# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
x = np.linspace(0,12,10)
y = x

# %%
img = mpimg.imread('img.jpg')

plt.imshow(img)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(235.5), np.float64(294.5), np.float64(-0.5))

# %%
cropped_img = img[50:200,100:250] #crop: rows 50-200, cols 100-250
plt.imshow(cropped_img)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(135.5), np.float64(149.5), np.float64(-0.5))

# %%
plt.plot(x,y, color="darkgreen",linewidth='2.5',markersize=0)
