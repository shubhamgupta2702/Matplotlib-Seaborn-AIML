# %% [markdown]
# **Plot**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,10,12)
x
y = x**2
y
# Out:
# array([  0.        ,   0.82644628,   3.30578512,   7.43801653,
#         13.2231405 ,  20.66115702,  29.75206612,  40.49586777,
#         52.89256198,  66.94214876,  82.6446281 , 100.        ])

# %%
plt.plot(x, y)
plt.title('Hello World!')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
# Out:
# Text(0, 0.5, 'Y-axis')
