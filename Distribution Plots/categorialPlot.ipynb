# %% [markdown]
# **Categorial Data Plots**
#
# now lets discuss using seaborn to plot categorial data. there are a few main plot types for this:
#
# **1.boxplot**
# **2.violinplot**
# **3.stripplot**
# **4.swarmplot**
# **5.barplot**
# **6.countplot**
#
# discussing examples of each...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.countplot(df['sex'])
# Out:
# <Axes: xlabel='count', ylabel='sex'>

# %%
sns.countplot(x =df['sex'], hue=df['smoker'])
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(x = df['day'],hue=df['sex'])
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.countplot(df['time'])
# Out:
# <Axes: xlabel='count', ylabel='time'>

# %%
sns.countplot(df['total_bill'])
# Out:
# <Axes: ylabel='count'>

# %%
# x-axis have categorical data
# y-axis have quantitative data
sns.barplot(x = df['sex'], y = df['tip'])
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %% [markdown]
# **you can change the estimator object to your own function, that converts a vector to a scalar Mean(default):**
# np.mean
# np.median
# np.sum
# np.std
# len
# np.min
# np.max

# %%
import numpy as np
sns.barplot(x = df['sex'], y=df['total_bill'], estimator=np.sum)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(x = df['sex'], y=df['tip'], estimator=np.sum)
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
# x-axis contains quantitative data.
#y-axis contains qualitative data or categorical data.
sns.boxplot(x = 'tip', y = 'day',data=df, palette='rainbow')
# Out:
# C:\Users\shubh\AppData\Local\Temp\ipykernel_16536\3022046920.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x = 'tip', y = 'day',data=df, palette='rainbow')
# <Axes: xlabel='tip', ylabel='day'>

# %%
sns.violinplot(x='day', y='total_bill', data=df)
# it shows distribution - area spread shown and also data with more data.
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# **stripplot and swarmplot**

# %%
sns.stripplot(x = 'day', y = 'total_bill', data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x = 'day', y = 'total_bill', data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x = 'tip', y = 'day', data=df)
sns.swarmplot(x = 'tip', y = 'day', data=df)
# Out:
# c:\Users\shubh\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 9.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\shubh\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 10.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='tip', ylabel='day'>
# c:\Users\shubh\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 8.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
